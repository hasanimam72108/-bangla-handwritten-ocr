# %% [markdown]
# # Bangla Handwritten Sentence Recognition OCR
# ### Kaggle Training Notebook
#
# **IMPORTANT**: This notebook requires two Kaggle Datasets added via **+Add Data**:
# 1. `joebeachcapital/handwritten-text-recognition-bongabdo`
# 2. `ayanwap7/banglawriting-with-page-level-annotations`
#
# See the `notebooks/kaggle_cells/` folder for individual cell-by-cell code files.

# %% [markdown]
# ## Instructions
#
# Do NOT use this .ipynb file directly. Instead, open each file from
# `notebooks/kaggle_cells/` in order (00_README_CELL_ORDER.txt shows the order)
# and paste each into a separate code cell.
#
# The cell order is:
# 1. 01_clone_repo.py
# 2. 02_install_deps.py
# 3. 03_load_datasets.py
# 4. 04_save_images.py
# 5. 05_show_stats.py
# 6. 06_split_dataset.py
# 7. 07_train_model.py
# 8. 08_train_bpe_optional.py (skip if not needed)
# 9. 09_evaluate.py
# 10. 10_display_test_samples.py
# 11. 11_predict_image_function.py
# 12. 12_test_generalization.py
# 13. 13_upload_own_image.py
# 14. 14_set_custom_image.py
# 15. 15_run_custom_prediction.py
# 16. 16_export_model.py
